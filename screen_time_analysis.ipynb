# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Screentime-App-Details.csv')
df
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %% [markdown]
# #Lets first see Social Media Data as a whole

# %% [markdown]
# Data

# %%
socialMediaData=df.loc[:,['Date','Usage','Notifications','Times opened']]
socialMediaData
# Out:
#           Date  Usage  Notifications  Times opened
# 0   08/26/2022     38             70            49
# 1   08/27/2022     39             43            48
# 2   08/28/2022     64            231            55
# 3   08/29/2022     14             35            23
# 4   08/30/2022      3             19             5
# 5   08/31/2022     19             25            20
# 6   09/01/2022     44             23            57
# 7   09/02/2022     16             28            22
# 8   09/03/2022     27             15            25
# 9   09/04/2022     72             29            30
# 10  09/05/2022     42             24            51
# 11  09/06/2022     19             34            25
# 12  09/07/2022     38             23            19
# 13  09/08/2022     71             48            43
# 14  09/09/2022     43             68            70
# 15  09/10/2022     45             71            70
# 16  09/11/2022     94            180            95
# ...

# %%
socialMediaData=socialMediaData.groupby('Date').sum()
socialMediaData
# Out:
#             Usage  Notifications  Times opened
# Date
# 08/26/2022    120            279           154
# 08/27/2022    108            154           116
# 08/28/2022    194            414           141
# 08/29/2022     73            192            97
# 08/30/2022    131            265            92
# 08/31/2022    127            194            97
# 09/01/2022     67            122           104
# 09/02/2022     92            172           125
# 09/03/2022     28             95            41
# 09/04/2022     78             67            63
# 09/05/2022    168            242           172
# 09/06/2022    110            239           135
# 09/07/2022    198            235           102
# 09/08/2022    140            265           125
# 09/09/2022    162            473           262
# 09/10/2022    148            237           149
# 09/11/2022    297            353           187
# 09/12/2022    296            389           274
# 09/13/2022     88            198           130
# ...

# %%
socialMediaData.describe()
# Out:
#             Usage  Notifications  Times opened
# count   27.000000      27.000000     27.000000
# mean   130.074074     235.407407    122.962963
# std     71.840061      92.588112     54.017434
# min     28.000000      67.000000     41.000000
# 25%     76.000000     190.500000     94.000000
# 50%    110.000000     221.000000    116.000000
# 75%    165.000000     269.500000    139.000000
# max    297.000000     473.000000    274.000000

# %%
socialMediaMean=df['Usage'].mean().round(2)
socialMediaMaxRow=df.loc[df['Usage'].idxmax()]
SMMaxdate=socialMediaMaxRow['Date']
SMMaxtime=socialMediaMaxRow['Usage']
print(f"The user's average time on social Media is {socialMediaMean} mins")
print(f"User's maximum screen time was on {SMMaxdate} of {SMMaxtime} mins")
# Out:
# The user's average time on social Media is 65.04 mins
# User's maximum screen time was on09/18/2022 of 244 mins

# %% [markdown]
# ## Ploting Usage(Social Media)-Week wise

# %% [markdown]
# #First Week

# %%
y=socialMediaData['Usage'][:6]
x=np.arange(26,32)
plt.plot(x,y)
plt.title("Last week of August")
plt.ylabel("Time in mins")
plt.xlabel("Date")
plt.show()

# %% [markdown]
# #Second week

# %%
x=np.arange(1,8)
y=socialMediaData['Usage'][6:6+7]
plt.plot(x,y)
plt.title('First week of September')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %% [markdown]
# #Third Week

# %%
x=np.arange(8,8+7)
y=socialMediaData['Usage'][13:13+7]
plt.plot(x,y)
plt.title('Second week of September')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %% [markdown]
# #Fourth Week

# %%
x=np.arange(15,22)
y=socialMediaData['Usage'][20:20+7]
plt.plot(x,y)
plt.title('Third week of September')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %% [markdown]
# Hypothesis 1-Weekdays and weekends exhibit different patterns of screen time and user engagement.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Screentime-App-Details.csv')
socialMediaData=df.loc[:,['Date','Usage','Notifications','Times opened']]
x=socialMediaData.index
y=socialMediaData['Usage']
plt.plot(x,y)
plt.title('Overall')
plt.xlabel('Date')
plt.xticks(rotation=60)
plt.ylabel('Time in mins')
sundays=['08/28/2022','09/04/2022','09/11/2022','09/18/2022']
for line in sundays:
    plt.axvline(x=line, color='black', linestyle='--')
plt.show()

# %% [markdown]
# Therefore we see that the user used social media more in the second week of september.The graph shows that the user spends an hour on social Media which is not bad.
# Conclusion:Social media app usage is higher on weekends compared to weekdays.

# %%
x=socialMediaData.index
y=socialMediaData['Usage']
plt.bar(x, y)
plt.xlabel('Date')
plt.ylabel("Time in mins")
plt.xticks(rotation=60)
plt.title("Social Media Screen time")
plt.show()

# %% [markdown]
# #Notifications(Social Media)

# %%
x=socialMediaData.index
y=socialMediaData['Notifications']
plt.bar(x, y)
plt.title("Notifications(Social Media)")
plt.xticks(rotation=60)
plt.xlabel('Date')
plt.ylabel('Number of notifications')
plt.show()

# %%
x=socialMediaData.index
y=socialMediaData['Times opened']
plt.bar(x, y)
plt.title("Times opened(Social Media)")
plt.xticks(rotation=60)
plt.xlabel('Date')
plt.ylabel('Times opened')
plt.show()

# %% [markdown]
# ##Now lets conisder Instagram Seperately

# %%
instadata=df
instadata.drop(df[df['App']!='Instagram'].index,inplace=True)
print(instadata)
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
instadata.describe()
# Out:
#             Usage  Notifications  Times opened
# count   27.000000      27.000000     27.000000
# mean    31.148148      44.296296     32.703704
# std     30.516961      52.310328     28.707832
# min      1.000000       8.000000      2.000000
# 25%      3.500000      14.000000      5.000000
# 50%     19.000000      25.000000     25.000000
# 75%     43.500000      46.500000     50.000000
# max    114.000000     231.000000    102.000000

# %%
instamean=instadata['Usage'].mean().round(2)
print(f'Average time spent on instagram is {instamean} mins')
instaMaxUse=instadata['Usage'].max()
max_row = df.loc[df['Usage'].idxmax()]
InstaMaxDate=max_row['Date']
instaMaxUsage=max_row['Usage']
print(f'Instagram was used most on {InstaMaxDate} for {instaMaxUsage} mins')
# Out:
# Average time spent on instagram is 31.15 mins
# Instagram was used most on 09/12/2022 for 114 mins

# %% [markdown]
# #Instagram Usage Week wise

# %%
y=instadata['Usage'][:6]
x=np.arange(26,32)
plt.plot(x,y)
plt.title("Last week of August(Instagram)")
plt.ylabel("Time in mins")
plt.xlabel("Date")
plt.show()

# %%
x=np.arange(1,8)
y=instadata['Usage'][6:6+7]
plt.plot(x,y)
plt.title('First week of September(Instagram)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
x=np.arange(8,8+7)
y=instadata['Usage'][13:13+7]
plt.plot(x,y)
plt.title('Second week of September(Instagram)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
x=np.arange(15,22)
y=instadata['Usage'][20:20+7]
plt.plot(x,y)
plt.title('Third week of September(Instagram)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
x=np.arange(1,28)
y=instadata['Usage']
plt.plot(x,y)
plt.title('Overall(Instagram)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %% [markdown]
# The graph clearly shows that the user had significantly reduced instagram screen time.Mostly used in the second week of september

# %%
x=instadata['Date']
y=instadata['Usage']
plt.bar(x, y)
plt.xlabel('Date')
plt.ylabel("Time in mins")
plt.xticks(rotation=60)
plt.title("Instagram Screen time")
plt.show()

# %% [markdown]
# #Notifications-Instagram

# %%
x=instadata['Date']
y=instadata['Notifications']
plt.bar(x, y)
plt.title("Notifications(Instagram)")
plt.xticks(rotation=60)
plt.xlabel('Date')
plt.ylabel('Number of notifications')
plt.show()

# %%
x=instadata['Date']
y=instadata['Times opened']
plt.bar(x, y)
plt.title("Times Opened(Instagram)")
plt.xticks(rotation=60)
plt.xlabel('Date')
plt.ylabel('Times opened')
plt.show()

# %% [markdown]
# #Lets consider Whatsapp seperately

# %%
whatsappData=df
whatsappData.drop(df[df['App']!='Whatsapp'].index,inplace=True)
print(whatsappData)
# Out:
#           Date  Usage  Notifications  Times opened       App
# 27  08/26/2022     82            209           105  Whatsapp
# 28  08/27/2022     69            111            68  Whatsapp
# 29  08/28/2022    130            183            86  Whatsapp
# 30  08/29/2022     59            157            74  Whatsapp
# 31  08/30/2022    128            246            87  Whatsapp
# 32  08/31/2022    108            169            77  Whatsapp
# 33  09/01/2022     23             99            47  Whatsapp
# 34  09/02/2022     76            144           103  Whatsapp
# 35  09/03/2022      1             80            16  Whatsapp
# 36  09/04/2022      6             38            33  Whatsapp
# 37  09/05/2022    126            218           121  Whatsapp
# 38  09/06/2022     91            205           110  Whatsapp
# 39  09/07/2022    160            212            83  Whatsapp
# 40  09/08/2022     69            217            82  Whatsapp
# ...

# %%
whatsappData.describe()
# Out:
#             Usage  Notifications  Times opened
# count   27.000000      27.000000     27.000000
# mean    98.925926     191.111111     90.259259
# std     60.133778      72.516488     37.054630
# min      1.000000      38.000000     16.000000
# 25%     66.500000     161.500000     71.000000
# 50%     82.000000     183.000000     86.000000
# 75%    127.000000     214.500000    105.000000
# max    244.000000     405.000000    192.000000

# %%
whatsappMean=whatsappData['Usage'].mean().round(2)
print(f'Average time spent on Whatsapp is {whatsappMean} mins')
whatsappMaxUse=whatsappData['Usage'].max()
max_row = df.loc[df['Usage'].idxmax()]
whatsappMaxDate=max_row['Date']
whatsappMaxUsage=max_row['Usage']
print(f'Instagram was used most on {whatsappMaxDate} for {whatsappMaxUsage} mins')
# Out:
# Average time spent on Whatsapp is 98.93 mins
# Instagram was used most on 09/18/2022 for 244 mins

# %% [markdown]
# #Whatsapp Usage-Week wise

# %%
y=whatsappData['Usage'][:6]
x=np.arange(26,32)
plt.plot(x,y)
plt.title("Last week of August(Whatsapp)")
plt.ylabel("Time in mins")
plt.xlabel("Date")
plt.show()

# %%
x=np.arange(1,8)
y=whatsappData['Usage'][6:6+7]
plt.plot(x,y)
plt.title('First week of September(Whatsapp)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
x=np.arange(8,8+7)
y=whatsappData['Usage'][13:13+7]
plt.plot(x,y)
plt.title('Second week of September(Whatsapp)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
x=np.arange(15,22)
y=whatsappData['Usage'][20:20+7]
plt.plot(x,y)
plt.title('Third week of September(Whatsapp)')
plt.xlabel('Date')
plt.ylabel('Time in mins')
plt.show()

# %%
y=whatsappData['Usage']
plt.plot(y)
plt.title('Overall(Whatsapp)')
plt.xlabel('Date')
plt.xticks(rotation = 60)
plt.ylabel('Time in mins')
plt.show()

# %% [markdown]
# This shows that the user uses more whatsapp and that after the second week of september he/she had redueced the use of instagram.The graph also shows that with increase in technologies the average time spent on social media apps is risng.

# %%
x=whatsappData['Date']
y=whatsappData['Usage']
plt.bar(x, y)
plt.xlabel('Date')
plt.ylabel("Time in mins")
plt.xticks(rotation=60)
plt.title("Whatsapp Screen time")
plt.show()

# %%
x=whatsappData['Date']
y=whatsappData['Notifications']
plt.bar(x, y)
plt.xlabel('Date')
plt.ylabel("Number")
plt.xticks(rotation=60)
plt.title("Whatsapp Notifications")
plt.show()

# %%
x=whatsappData['Date']
y=whatsappData['Times opened']
plt.bar(x, y)
plt.xlabel('Date')
plt.ylabel("No of times opened")
plt.xticks(rotation=60)
plt.title("Whatsapp Times opened")
plt.show()

# %%
merged_data = pd.merge(whatsappData, instadata, on='Date', how='outer')
plt.plot(merged_data['Date'], merged_data['Usage_x'], label='WhatsApp')
plt.plot(merged_data['Date'], merged_data['Usage_y'], label='Instagram')

plt.title('Overall Usage Comparison')
plt.xlabel('Date')
plt.xticks(rotation=60)
plt.ylabel('Time in mins')
hour = 60

sundays=['08/28/2022','09/04/2022','09/11/2022','09/18/2022']
for line in sundays:
    plt.axvline(x=line, color='black', linestyle='--')
plt.legend()

plt.show()

# %% [markdown]
# This Graph shows that people use social Media more on weekends than normal weekdays.Also it is evident that the user had reduced the instagram usage from the third week of september

# %%
import plotly.express as px
x=whatsappData['Notifications']
y=whatsappData['Usage']
fig =px.scatter(whatsappData,'Notifications','Usage',size='Notifications',trendline='ols',title='Whatsapp Notfications vs Usage')
# plt.xlabel('Notifications')
# plt.ylabel("Time in mins")
# plt.xticks(rotation=60)
# plt.title("Whatsapp Notifications vs Usage")
# plt.plot([100,250],[0,200])
# plt.show()
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=socialMediaData['Notifications']
y=socialMediaData['Usage']
plt.scatter(x, y)
plt.xlabel('Notifications')
plt.ylabel("Time in mins")
plt.xticks(rotation=60)
plt.title("Social Media Notifications vs Usage")
plt.plot([0,300],[0,150])
plt.show()

# %%
fig =px.scatter(socialMediaData,'Notifications','Usage',size='Notifications',trendline='ols')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y=instadata['Notifications']
x=instadata['Usage']
plt.scatter(x,y)
plt.xlabel('Time in mins')
plt.ylabel("Notifications")
plt.xticks(rotation=60)
plt.title("Instagram Usage vs Notifications")
plt.plot([40,0],[80,0])
plt.show()
